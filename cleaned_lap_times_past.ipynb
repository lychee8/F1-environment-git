# %%
import pandas as pd

df = pd.read_csv("lap_times.csv")

# print(df.head())
# print(df.isnull().sum())
print(df.dtypes)

# df['driverId']


df.columns =df.columns.str.strip()

df['raceId'] = pd.to_numeric(df['raceId'], errors='coerce')

df = df[df['raceId'] < 880]

# df['time'] = pd.to_numeric(df['time'], errors='coerce')

df.loc[(df['raceId'] >= 1) & (df['raceId'] <= 17), 'raceId'] = 2009
df.loc[(df['raceId'] >= 18) & (df['raceId'] <= 35), 'raceId'] = 2008
df.loc[(df['raceId'] >= 36) & (df['raceId'] <= 52), 'raceId'] = 2007
df.loc[(df['raceId'] >= 53) & (df['raceId'] <= 70), 'raceId'] = 2006
df.loc[(df['raceId'] >= 71) & (df['raceId'] <= 89), 'raceId'] = 2005
df.loc[(df['raceId'] >= 90) & (df['raceId'] <= 107), 'raceId'] = 2004
df.loc[(df['raceId'] >= 108) & (df['raceId'] <= 123), 'raceId'] = 2003
df.loc[(df['raceId'] >= 124) & (df['raceId'] <= 140), 'raceId'] = 2002
df.loc[(df['raceId'] >= 141) & (df['raceId'] <= 157), 'raceId'] = 2001
df.loc[(df['raceId'] >= 158) & (df['raceId'] <= 174), 'raceId'] = 2000
df.loc[(df['raceId'] >= 175) & (df['raceId'] <= 190), 'raceId'] = 1999
df.loc[(df['raceId'] >= 191) & (df['raceId'] <= 206), 'raceId'] = 1998
df.loc[(df['raceId'] >= 207) & (df['raceId'] <= 223), 'raceId'] = 1997
df.loc[(df['raceId'] >= 224) & (df['raceId'] <= 239), 'raceId'] = 1996
df.loc[(df['raceId'] >= 240) & (df['raceId'] <= 256), 'raceId'] = 1995
df.loc[(df['raceId'] >= 257) & (df['raceId'] <= 272), 'raceId'] = 1994
df.loc[(df['raceId'] >= 273) & (df['raceId'] <= 288), 'raceId'] = 1993
df.loc[(df['raceId'] >= 289) & (df['raceId'] <= 304), 'raceId'] = 1992
df.loc[(df['raceId'] >= 305) & (df['raceId'] <= 320), 'raceId'] = 1991
df.loc[(df['raceId'] >= 321) & (df['raceId'] <= 336), 'raceId'] = 1990
df.loc[(df['raceId'] >= 337) & (df['raceId'] <= 355), 'raceId'] = 2010
df.loc[(df['raceId'] >= 356) & (df['raceId'] <= 371), 'raceId'] = 1989
df.loc[(df['raceId'] >= 372) & (df['raceId'] <= 387), 'raceId'] = 1988
df.loc[(df['raceId'] >= 388) & (df['raceId'] <= 403), 'raceId'] = 1987
df.loc[(df['raceId'] >= 404) & (df['raceId'] <= 419), 'raceId'] = 1986
df.loc[(df['raceId'] >= 420) & (df['raceId'] <= 435), 'raceId'] = 1985
df.loc[(df['raceId'] >= 436) & (df['raceId'] <= 451), 'raceId'] = 1984
df.loc[(df['raceId'] >= 452) & (df['raceId'] <= 466), 'raceId'] = 1983
df.loc[(df['raceId'] >= 467) & (df['raceId'] <= 482), 'raceId'] = 1982
df.loc[(df['raceId'] >= 483) & (df['raceId'] <= 497), 'raceId'] = 1981
df.loc[(df['raceId'] >= 498) & (df['raceId'] <= 511), 'raceId'] = 1980
df.loc[(df['raceId'] >= 512) & (df['raceId'] <= 526), 'raceId'] = 1979
df.loc[(df['raceId'] >= 527) & (df['raceId'] <= 542), 'raceId'] = 1978
df.loc[(df['raceId'] >= 543) & (df['raceId'] <= 560), 'raceId'] = 1977
df.loc[(df['raceId'] >= 561) & (df['raceId'] <= 575), 'raceId'] = 1976
df.loc[(df['raceId'] >= 576) & (df['raceId'] <= 589), 'raceId'] = 1975
df.loc[(df['raceId'] >= 590) & (df['raceId'] <= 604), 'raceId'] = 1974
df.loc[(df['raceId'] >= 605) & (df['raceId'] <= 619), 'raceId'] = 1973
df.loc[(df['raceId'] >= 620) & (df['raceId'] <= 631), 'raceId'] = 1972
df.loc[(df['raceId'] >= 632) & (df['raceId'] <= 642), 'raceId'] = 1971
df.loc[(df['raceId'] >= 643) & (df['raceId'] <= 655), 'raceId'] = 1970
df.loc[(df['raceId'] >= 656) & (df['raceId'] <= 666), 'raceId'] = 1969
df.loc[(df['raceId'] >= 667) & (df['raceId'] <= 678), 'raceId'] = 1968
df.loc[(df['raceId'] >= 679) & (df['raceId'] <= 689), 'raceId'] = 1967
df.loc[(df['raceId'] >= 690) & (df['raceId'] <= 698), 'raceId'] = 1966
df.loc[(df['raceId'] >= 699) & (df['raceId'] <= 708), 'raceId'] = 1965
df.loc[(df['raceId'] >= 709) & (df['raceId'] <= 718), 'raceId'] = 1964
df.loc[(df['raceId'] >= 719) & (df['raceId'] <= 728), 'raceId'] = 1963
df.loc[(df['raceId'] >= 729) & (df['raceId'] <= 737), 'raceId'] = 1962
df.loc[(df['raceId'] >= 738) & (df['raceId'] <= 745), 'raceId'] = 1961
df.loc[(df['raceId'] >= 746) & (df['raceId'] <= 755), 'raceId'] = 1960
df.loc[(df['raceId'] >= 756) & (df['raceId'] <= 764), 'raceId'] = 1959
df.loc[(df['raceId'] >= 765) & (df['raceId'] <= 775), 'raceId'] = 1958
df.loc[(df['raceId'] >= 776) & (df['raceId'] <= 783), 'raceId'] = 1957
df.loc[(df['raceId'] >= 784) & (df['raceId'] <= 791), 'raceId'] = 1956
df.loc[(df['raceId'] >= 792) & (df['raceId'] <= 798), 'raceId'] = 1955
df.loc[(df['raceId'] >= 799) & (df['raceId'] <= 807), 'raceId'] = 1954
df.loc[(df['raceId'] >= 808) & (df['raceId'] <= 816), 'raceId'] = 1953
df.loc[(df['raceId'] >= 817) & (df['raceId'] <= 824), 'raceId'] = 1952
df.loc[(df['raceId'] >= 825) & (df['raceId'] <= 832), 'raceId'] = 1951
df.loc[(df['raceId'] >= 833) & (df['raceId'] <= 839), 'raceId'] = 1950
df.loc[(df['raceId'] >= 840) & (df['raceId'] <= 859), 'raceId'] = 2011
df.loc[(df['raceId'] >= 860) & (df['raceId'] <= 879), 'raceId'] = 2012

# for i in range (122589,122596):
df.drop([], axis = 0, inplace = True)

# for i in range (119660,119670):
#     df.drop([i], axis = 0, inplace = True)

df = df.sort_values(by='raceId', ascending=True)


print(df.head())


df.to_csv("cleaned_lap_times_past.csv", index=False)
# Out:
# raceId           int64
# driverId         int64
# lap              int64
# position         int64
# time            object
# milliseconds     int64
# dtype: object
#         raceId  driverId  lap  position      time  milliseconds
# 122592    1996        57   35         2  1:31.221         91221
# 119667    1996        63   43         6  1:27.722         87722
# 119666    1996        63   42         6  1:27.684         87684
# 119665    1996        63   41         6  1:28.504         88504
# 119664    1996        63   40         7  1:28.190         88190
